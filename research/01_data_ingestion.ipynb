# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\zeyne\\MLFlow\\research'

# %%
os.chdir("../")

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class DataIngestionConfig:
    root_dir:Path
    source_URL:str
    local_data_file:str
    unzip_dir:Path

# %%
from src.ML_Project_w_MLFlow.constants import *
from src.ML_Project_w_MLFlow.utils.common import read_yaml,create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH,
        schema_filepath = SCHEMA_FILE_PATH ):


        self.config=read_yaml(config_filepath)
        self.params=read_yaml(params_filepath)
        self.schema=read_yaml(schema_filepath)


        create_directories([self.config.artifacts_root])
    


    def get_data_ingestion_config(self)->DataIngestionConfig:
        config=self.config.data_ingestion

        create_directories([config.root_dir])

        data_ingestion_config=DataIngestionConfig(
          root_dir=config.root_dir,
          source_URL=config.source_URL,
          local_data_file=config.local_data_file,
          unzip_dir=config.unzip_dir
        )

        return data_ingestion_config

# %%
import os 
import urllib.request as request
import zipfile
from src.ML_Project_w_MLFlow import logger
from src.ML_Project_w_MLFlow.utils.common import get_size

# %%
class DataIngestion:
    def __init__(self,config:DataIngestionConfig):
        self.config=config



    def download_file(self):
        if not os.path.exists(self.config.local_data_file):
            filename,headers= request.urlretrieve(
                url=self.config.source_URL,
                filename=self.config.local_data_file
            )
            logger.info(f"{filename} download! following info:  {headers}")
        else:
            logger.info(f"file is already exists,size:{get_size(Path(self.config.local_data_file))}")

            
    def extract_zip_file(self):


        unzip_path=self.config.unzip_dir
        os.makedirs(unzip_path,exist_ok=True)
        with zipfile.ZipFile(self.config.local_data_file, 'r') as zip_ref:
            zip_ref.extractall(unzip_path)

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\zeyne\MLFlow

# %%
try:
    config=ConfigurationManager()
    data_ingestion_config=config.get_data_ingestion_config()
    data_ingestion=DataIngestion(config=data_ingestion_config)
    data_ingestion.download_file()
    data_ingestion.extract_zip_file()

except Exception as e :
    raise e
# Out:
# [2025-07-28 20:58:38,881:INFO: common: yaml file:config\config.yaml loaded successfully]
# [2025-07-28 20:58:38,883:INFO: common: yaml file:params.yaml loaded successfully]
# [2025-07-28 20:58:38,887:INFO: common: yaml file:schema.yaml loaded successfully]
# [2025-07-28 20:58:38,900:INFO: 3716584484: file is already exists,size:~175 KB]
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\zeyne\anaconda3\Lib\logging\__init__.py", line 1151, in emit
#     msg = self.format(record)
#   File "c:\Users\zeyne\anaconda3\Lib\logging\__init__.py", line 999, in format
#     return fmt.format(record)
#            ~~~~~~~~~~^^^^^^^^
#   File "c:\Users\zeyne\anaconda3\Lib\logging\__init__.py", line 712, in format
#     record.message = record.getMessage()
#                      ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\zeyne\anaconda3\Lib\logging\__init__.py", line 400, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\zeyne\anaconda3\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "c:\Users\zeyne\anaconda3\Lib\asyncio\base_events.py", line 2042, in _run_once
#     handle._run()
#   File "c:\Users\zeyne\anaconda3\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\zeyne\AppData\Local\Temp\ipykernel_13120\1627115222.py", line 2, in <module>
#     config=ConfigurationManager()
#   File "C:\Users\zeyne\AppData\Local\Temp\ipykernel_13120\3822834101.py", line 14, in __init__
#     create_directories([self.config.artifacts_root])
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ensure\main.py", line 835, in __call__
#     return self.f(*args, **kwargs)
#   File "c:\Users\zeyne\MLFlow\src\ML_Project_w_MLFlow\utils\common.py", line 43, in create_directories
#     logger.info(f"created directory at:",{path})
# Message: 'created directory at:'
# Arguments: ({'artifacts'},)
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\zeyne\anaconda3\Lib\logging\__init__.py", line 1151, in emit
#     msg = self.format(record)
#   File "c:\Users\zeyne\anaconda3\Lib\logging\__init__.py", line 999, in format
#     return fmt.format(record)
#            ~~~~~~~~~~^^^^^^^^
#   File "c:\Users\zeyne\anaconda3\Lib\logging\__init__.py", line 712, in format
#     record.message = record.getMessage()
#                      ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\zeyne\anaconda3\Lib\logging\__init__.py", line 400, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\zeyne\anaconda3\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "c:\Users\zeyne\anaconda3\Lib\asyncio\base_events.py", line 2042, in _run_once
#     handle._run()
#   File "c:\Users\zeyne\anaconda3\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\zeyne\AppData\Local\Temp\ipykernel_13120\1627115222.py", line 2, in <module>
#     config=ConfigurationManager()
#   File "C:\Users\zeyne\AppData\Local\Temp\ipykernel_13120\3822834101.py", line 14, in __init__
#     create_directories([self.config.artifacts_root])
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ensure\main.py", line 835, in __call__
#     return self.f(*args, **kwargs)
#   File "c:\Users\zeyne\MLFlow\src\ML_Project_w_MLFlow\utils\common.py", line 43, in create_directories
#     logger.info(f"created directory at:",{path})
# Message: 'created directory at:'
# Arguments: ({'artifacts'},)
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\zeyne\anaconda3\Lib\logging\__init__.py", line 1151, in emit
#     msg = self.format(record)
#   File "c:\Users\zeyne\anaconda3\Lib\logging\__init__.py", line 999, in format
#     return fmt.format(record)
#            ~~~~~~~~~~^^^^^^^^
#   File "c:\Users\zeyne\anaconda3\Lib\logging\__init__.py", line 712, in format
#     record.message = record.getMessage()
#                      ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\zeyne\anaconda3\Lib\logging\__init__.py", line 400, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\zeyne\anaconda3\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "c:\Users\zeyne\anaconda3\Lib\asyncio\base_events.py", line 2042, in _run_once
#     handle._run()
#   File "c:\Users\zeyne\anaconda3\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\zeyne\AppData\Local\Temp\ipykernel_13120\1627115222.py", line 3, in <module>
#     data_ingestion_config=config.get_data_ingestion_config()
#   File "C:\Users\zeyne\AppData\Local\Temp\ipykernel_13120\3822834101.py", line 21, in get_data_ingestion_config
#     create_directories([config.root_dir])
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ensure\main.py", line 835, in __call__
#     return self.f(*args, **kwargs)
#   File "c:\Users\zeyne\MLFlow\src\ML_Project_w_MLFlow\utils\common.py", line 43, in create_directories
#     logger.info(f"created directory at:",{path})
# Message: 'created directory at:'
# Arguments: ({'artifacts/data_ingestion'},)
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\zeyne\anaconda3\Lib\logging\__init__.py", line 1151, in emit
#     msg = self.format(record)
#   File "c:\Users\zeyne\anaconda3\Lib\logging\__init__.py", line 999, in format
#     return fmt.format(record)
#            ~~~~~~~~~~^^^^^^^^
#   File "c:\Users\zeyne\anaconda3\Lib\logging\__init__.py", line 712, in format
#     record.message = record.getMessage()
#                      ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\zeyne\anaconda3\Lib\logging\__init__.py", line 400, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\zeyne\anaconda3\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "c:\Users\zeyne\anaconda3\Lib\asyncio\base_events.py", line 2042, in _run_once
#     handle._run()
#   File "c:\Users\zeyne\anaconda3\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\zeyne\AppData\Local\Temp\ipykernel_13120\1627115222.py", line 3, in <module>
#     data_ingestion_config=config.get_data_ingestion_config()
#   File "C:\Users\zeyne\AppData\Local\Temp\ipykernel_13120\3822834101.py", line 21, in get_data_ingestion_config
#     create_directories([config.root_dir])
#   File "c:\Users\zeyne\anaconda3\Lib\site-packages\ensure\main.py", line 835, in __call__
#     return self.f(*args, **kwargs)
#   File "c:\Users\zeyne\MLFlow\src\ML_Project_w_MLFlow\utils\common.py", line 43, in create_directories
#     logger.info(f"created directory at:",{path})
# Message: 'created directory at:'
# Arguments: ({'artifacts/data_ingestion'},)
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In[16], line 9
#       6     data_ingestion.extract_zip_file()
#       8 except Exception as e :
# ----> 9     raise e
#
# Cell In[16], line 6
#       4     data_ingestion=DataIngestion(config=data_ingestion_config)
#       5     data_ingestion.download_file()
# ----> 6     data_ingestion.extract_zip_file()
#       8 except Exception as e :
#       9     raise e
#
# Cell In[10], line 23, in DataIngestion.extract_zip_file(self)
#      21 unzip_path=self.config.unzip_dir
#      22 os.makedirs(unzip_path,exist_ok=True)
# ---> 23 with zipfile.ZipFile(self.config.local_data_file, 'r') as zip_ref:
#      24     zip_ref.extractall(unzip_path)
#
# File c:\Users\zeyne\anaconda3\Lib\zipfile\__init__.py:1385, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1383 try:
#    1384     if mode == 'r':
# -> 1385         self._RealGetContents()
#    1386     elif mode in ('w', 'x'):
#    1387         # set the modified flag so central directory gets written
#    1388         # even if no files are added to the archive
#    1389         self._didModify = True
#
# File c:\Users\zeyne\anaconda3\Lib\zipfile\__init__.py:1452, in ZipFile._RealGetContents(self)
#    1450     raise BadZipFile("File is not a zip file")
#    1451 if not endrec:
# -> 1452     raise BadZipFile("File is not a zip file")
#    1453 if self.debug > 1:
#    1454     print(endrec)
#
# BadZipFile: File is not a zip file
